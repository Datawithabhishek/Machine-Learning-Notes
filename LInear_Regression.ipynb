# %% [markdown]
# <a href="https://colab.research.google.com/github/Klearpixeloff/Machine-Learning-Notes/blob/main/LInear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression
#
# Regression algorithms are used if there is a relationship between the input variable and the output variable. It is used for the prediction of continuous variables

# %% [markdown]
# # Linear Regression
#
# Linear regression algorithm shows a linear relationship between a dependent (y) and one or more independent (X) variables, hence called as linear regression.

# %% [markdown]
# LINEAR REGRESSION ARE ALSO KNOWN AS **OLS(Ordinary least squares)** OR **(linear least square)**

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ![images.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **EQUATION**
#
# Y = B0 + B1X + E
#
#
#
# Y= Dependent Variable (ACTUAL VALUE)
#
# X= Independent Variable (predictor Variable)
#
# B0= intercept of the line (Gives an additional degree of freedom)
#
# B1 = Linear regression coefficient (scale factor to each input value).
#
# ε = random erro

# %% [markdown]
# the **residual sum of squares (RSS)**, also known as the **sum of squared residuals (SSR)** or the **sum of squared errors of prediction (SSE)**, is the sum of the squares of residuals (deviations of predicted from actual empirical values of data).
#
# **Residual Sum of Squares (RSS) is defined and given by the following function:**

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# # Types
#
# **Simple Linear Regression:**
# If a single independent variable is used to predict the value of a numerical dependent variable, then such a Linear Regression algorithm is called Simple Linear Regression.
#
# **Multiple Linear regression:**
# If more than one independent variable is used to predict the value of a numerical dependent variable, then such a Linear Regression algorithm is called Multiple Linear Regression.

# %% [markdown]
# # linear regression estimators of parameters

# %% [markdown]
# ![WhatsApp Image 2023-02-07 at 8.26.03 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-07 at 8.26.04 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# BEST POSSIBLE LINE
#
# WITH INFINITE POSSIBLITIES OF VALUE WHICH PARAMETERS  CAN TAKE , HOW DO WE ARRIVE AT THE BEST POSSIBLE LINE WITH MINIMUM ITERATION

# %% [markdown]
# # GRADIENT DESCENT

# %% [markdown]
# **It's an optimization algo that helps Ml models to find out paths to a mini value
# using repeated steps**
#
# or
#
# **minimise cost function**

# %% [markdown]
# # How does it work

# %% [markdown]
# 1. minimise cost function
#
# 2. minimise cost function will also result in a lower error between the predicted and the actual value
#
# 3. it's used to minimise for linear regression

# %% [markdown]
# **mean squared error**
#
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# **note** whenever we minimise something
# we apply derivative

# %% [markdown]
# **cost function or loss function**
#
# after applying differentiate
#
#  we get this formula
#
#
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# **gradient descent formula**
#
#
#
# ![5.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-07 at 9.55.28 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # ASSUMPTION OF REGRESSION LINE

# %% [markdown]
# 1. Linear Relationship Between input and output
#
#
#
#
# ![6.png](data:image/png;base64,...)
#
# 2. No Multicollinearity
#
# detect multicollinearity :
#
# vif(variance inflation factor) = (1/1-Ri^2)
#
# **Multicollinearity** is a statistical concept where several independent variables in a model are correlated.
#
# **1** = not correlated
#
# **between 1 and 5** = moderately correlated
#
# **Greater than 5** = highly correlated
#
#
#
# 3. normality of residual
#
# mean of residual should be zero or close to zero as much as possible
#
# ![7.png](data:image/png;base64,...)
#
#
#
# 4. homoscedasticity(having the same scatter)
#
#
#
# ![Screenshot 2023-02-08 110719.png](data:image/png;base64,...)
#
#
#
# 5. No Autocorrelation of Errors
#
#
#
#
# ![8.png](data:image/png;base64,...)![10.png](data:image/png;base64,...)![9.png](data:image/png;base64,...)

# %% [markdown]
# # Feature scaling
#
# Its a  technique to standardize the independent features present in the data in a fixed range
